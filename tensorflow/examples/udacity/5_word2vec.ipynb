# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.093900
# Nearest to these: iverson, debugging, lawsuits, ly, euphrates, beechcraft, mcnally, waterfall,
# Nearest to often: slid, lei, lodged, cuzco, satisfactory, antacids, ivb, kabbalah,
# Nearest to than: circassians, sidra, invents, active, aries, typical, lancashire, dieu,
# Nearest to on: ota, katrina, ptolemaic, torch, tesla, spider, tilden, planks,
# Nearest to history: restrictions, exhaustion, ankh, shogunate, misrepresenting, suffragist, gulls, disrupted,
# Nearest to from: spoiling, chill, townspeople, astigmatism, astonishing, oakland, lan, cause,
# Nearest to people: redesign, disapproved, yale, mervyn, rhine, saharan, maligned, dispatches,
# Nearest to not: snow, identifier, recalling, edges, rbis, rotten, increments, synaptic,
# Nearest to d: taekwondo, diffeomorphism, supermassive, mainstream, finer, incapacitation, ceremonies, palembang,
# Nearest to at: dago, prick, thoroughbred, freeview, tls, pk, chewing, paley,
# Nearest to with: pluralistic, genitalia, exempted, inconsistency, steals, uematsu, kiel, extensive,
# Nearest to if: ninety, diverting, coeur, stubborn, andalusia, stud, caldwell, asmara,
# Nearest to is: opposed, buzzard, shown, guanine, triplet, hijacking, radioisotopes, disrespectful,
# Nearest to also: liberator, generally, metabolize, blond, replete, vivid, idioms, warranted,
# Nearest to united: alkane, graft, comb, converters, nand, buu, daphne, finno,
# Nearest to war: billings, delighted, alen, paraguayan, cultivars, rvi, becker, camcorder,
# Average loss at step 2000: 4.358173
# Average loss at step 4000: 3.866753
# Average loss at step 6000: 3.787835
# Average loss at step 8000: 3.685796
# Average loss at step 10000: 3.616914
# Nearest to these: lawsuits, nouveau, ly, potemkin, hak, drowning, jus, they,
# Nearest to often: narrowly, simply, joram, visceral, also, it, bunny, ashoka,
# Nearest to than: circassians, dieu, active, or, voyage, orchestras, aries, hot,
# Nearest to on: in, from, between, at, virchow, shock, ota, by,
# Nearest to history: suffragist, enumerable, exhaustion, ankh, old, restrictions, garuda, list,
# Nearest to from: into, in, upstream, during, on, theropod, townspeople, oakland,
# Nearest to people: soared, cobra, deputies, saharan, seeks, yale, deviating, property,
# Nearest to not: it, they, to, turbocharger, donkeys, avl, sculpted, also,
# Nearest to d: and, supra, ceremonies, supermassive, deaths, blogger, decrees, weil,
# Nearest to at: in, rick, on, by, mustang, same, near, paley,
# Nearest to with: between, in, by, for, through, inflict, listeners, amerindian,
# Nearest to if: andalusia, ninety, disagreements, abercrombie, scriptura, ewald, coeur, otherwise,
# Nearest to is: was, has, are, be, became, waxing, bridgeport, does,
# Nearest to also: generally, felsic, it, not, often, brownian, rulers, he,
# Nearest to united: nand, baton, alkane, graft, pentium, buu, variste, mould,
# Nearest to war: billings, alen, lusignan, ley, becker, slight, biola, cultivars,
# Average loss at step 12000: 3.606188
# Average loss at step 14000: 3.571158
# Average loss at step 16000: 3.412466
# Average loss at step 18000: 3.455451
# Average loss at step 20000: 3.539802
# Nearest to these: some, many, lawsuits, such, potemkin, all, which, nouveau,
# Nearest to often: sometimes, simply, also, usually, smugglers, which, lekhanya, bunny,
# Nearest to than: or, circassians, dieu, active, zork, forti, aries, foobar,
# Nearest to on: in, from, mervyn, at, spider, among, virchow, bonny,
# Nearest to history: suffragist, old, southward, amount, exhaustion, aim, enumerable, monarchy,
# Nearest to from: into, upstream, at, in, syllabic, oakland, through, on,
# Nearest to people: soared, cobra, seeks, deputies, coppersmith, impending, those, itosu,
# Nearest to not: they, usually, also, turbocharger, generally, donkeys, become, it,
# Nearest to d: b, weil, supra, incisors, supermassive, faisal, barrage, blogger,
# Nearest to at: in, during, from, denotation, on, with, murderer, near,
# Nearest to with: between, in, denotation, through, for, exempted, and, at,
# Nearest to if: when, abercrombie, scriptura, disagreements, andalusia, vulcan, piled, took,
# Nearest to is: was, are, has, be, were, malleus, makes, but,
# Nearest to also: generally, which, now, not, often, sometimes, who, still,
# Nearest to united: nand, baton, buu, functioned, tornadoes, pentium, refectory, graft,
# Nearest to war: billings, alen, monastic, biola, ley, celebrated, becker, lusignan,
# Average loss at step 22000: 3.503395
# Average loss at step 24000: 3.488453
# Average loss at step 26000: 3.481988
# Average loss at step 28000: 3.482177
# Average loss at step 30000: 3.504249
# Nearest to these: some, many, both, they, all, are, several, potemkin,
# Nearest to often: usually, sometimes, simply, generally, also, still, widely, there,
# Nearest to than: dieu, circassians, forti, active, or, zork, much, hot,
# Nearest to on: in, from, upon, among, through, about, mervyn, into,
# Nearest to history: amount, southward, old, consists, suffragist, abiotic, enumerable, climates,
# Nearest to from: into, through, on, during, in, of, sweeney, upstream,
# Nearest to people: soared, those, seeks, coppersmith, impending, torture, deputies, mcnally,
# Nearest to not: they, generally, usually, it, sculpted, still, premillennialism, also,
# Nearest to d: b, supra, ph, incisors, saves, authorize, supermassive, weil,
# Nearest to at: in, during, near, denotation, doggy, splintered, on, retractable,
# Nearest to with: between, in, through, for, when, listeners, by, sinti,
# Nearest to if: when, because, where, could, saw, scriptura, that, disagreements,
# Nearest to is: was, has, are, does, became, be, makes, bridgeport,
# Nearest to also: generally, now, often, still, sometimes, which, always, then,
# Nearest to united: nand, baton, pentium, buu, alkane, tornadoes, gzip, refectory,
# Nearest to war: alen, ley, monastic, biola, lusignan, satisfying, concepts, billings,
# Average loss at step 32000: 3.505661
# Average loss at step 34000: 3.494251
# Average loss at step 36000: 3.452346
# Average loss at step 38000: 3.297710
# Average loss at step 40000: 3.429654
# Nearest to these: many, some, both, several, they, which, different, such,
# Nearest to often: usually, sometimes, also, which, generally, simply, still, widely,
# Nearest to than: or, dieu, circassians, pissarro, much, forti, howl, pohjola,
# Nearest to on: upon, testimonium, at, virchow, admirals, within, bonny, macron,
# Nearest to history: list, southward, philosophy, climates, portals, leiden, consists, abiotic,
# Nearest to from: into, through, during, wove, dinosaurs, bailiwicks, sophisticated, mosque,
# Nearest to people: soared, deputies, those, havens, mcnally, impending, ageing, orbital,
# Nearest to not: usually, they, still, it, premillennialism, generally, clearly, we,
# Nearest to d: b, supra, saves, UNK, taekwondo, supermassive, pinyin, ph,
# Nearest to at: near, during, in, on, doggy, cics, muggles, efnet,
# Nearest to with: between, when, exempted, stanford, without, listeners, blaine, by,
# Nearest to if: when, because, where, vulcan, for, is, holds, piled,
# Nearest to is: was, are, has, be, makes, malleus, if, became,
# Nearest to also: often, still, sometimes, which, now, generally, usually, always,
# Nearest to united: nand, baton, buu, tornadoes, pentium, alkane, gzip, vladislav,
# Nearest to war: ley, alen, lusignan, billings, celebrated, monastic, satisfying, biola,
# Average loss at step 42000: 3.439721
# Average loss at step 44000: 3.453090
# Average loss at step 46000: 3.448091
# Average loss at step 48000: 3.353412
# Average loss at step 50000: 3.383065
# Nearest to these: many, some, both, several, such, which, their, various,
# Nearest to often: sometimes, usually, generally, also, commonly, which, widely, still,
# Nearest to than: dieu, or, circassians, much, hot, pissarro, pohjola, but,
# Nearest to on: upon, in, within, among, into, mervyn, through, bahn,
# Nearest to history: list, climates, philosophy, consists, leiden, enumerable, southward, portals,
# Nearest to from: into, through, in, during, sweeney, after, upstream, on,
# Nearest to people: children, years, men, manometer, atlantans, soared, those, impending,
# Nearest to not: usually, premillennialism, now, they, iterating, we, still, there,
# Nearest to d: b, supra, e, saves, pinyin, n, supermassive, ph,
# Nearest to at: during, near, denotation, on, in, minogue, doggy, within,
# Nearest to with: between, exempted, listeners, into, when, received, while, by,
# Nearest to if: when, where, although, because, vulcan, could, krause, newsweek,
# Nearest to is: was, are, has, became, makes, contains, calderas, filesystem,
# Nearest to also: often, still, which, now, usually, sometimes, generally, who,
# Nearest to united: nand, baton, buu, pentium, directx, graft, tornadoes, heil,
# Nearest to war: alen, ley, billings, lusignan, celebrated, satisfying, monastic, wanders,
# Average loss at step 52000: 3.434212
# Average loss at step 54000: 3.427961
# Average loss at step 56000: 3.435804
# Average loss at step 58000: 3.399892
# Average loss at step 60000: 3.392680
# Nearest to these: many, some, both, several, such, those, their, are,
# Nearest to often: sometimes, usually, commonly, generally, still, also, widely, now,
# Nearest to than: dieu, or, much, and, but, circassians, pissarro, far,
# Nearest to on: upon, bonny, through, in, mervyn, within, funimation, into,
# Nearest to history: vestal, portals, list, philosophy, cambridge, homeless, monarchy, success,
# Nearest to from: through, into, in, during, sweeney, electrician, after, before,
# Nearest to people: men, children, those, deputies, ageing, soared, women, manometer,
# Nearest to not: usually, still, now, clearly, there, they, it, ath,
# Nearest to d: b, supra, saves, r, pinyin, j, n, e,
# Nearest to at: in, during, near, within, minogue, doggy, before, elmo,
# Nearest to with: between, when, while, although, without, exempted, sab, among,
# Nearest to if: when, where, because, although, though, for, could, before,
# Nearest to is: was, are, has, does, although, makes, but, becomes,
# Nearest to also: still, now, often, sometimes, generally, usually, never, actually,
# Nearest to united: nand, baton, tornadoes, buu, shaded, bca, reading, heil,
# Nearest to war: satisfying, alen, lusignan, billings, ley, disbandment, wanders, celebrated,
# Average loss at step 62000: 3.242672
# Average loss at step 64000: 3.253673
# Average loss at step 66000: 3.401059
# Average loss at step 68000: 3.392942
# Average loss at step 70000: 3.362164
# Nearest to these: some, such, many, several, which, those, their, both,
# Nearest to often: sometimes, usually, commonly, generally, still, widely, also, now,
# Nearest to than: or, dieu, much, circassians, detects, pissarro, amoeba, dsp,
# Nearest to on: upon, through, in, within, bonny, mervyn, disprove, at,
# Nearest to history: list, vestal, cambridge, universitat, enumerable, posix, biography, philosophy,
# Nearest to from: through, into, toward, defoe, in, before, upstream, across,
# Nearest to people: men, children, women, those, deputies, mujahideen, americans, citizens,
# Nearest to not: now, still, generally, usually, clearly, greatly, partially, premillennialism,
# Nearest to d: b, pinyin, n, supra, saves, r, f, e,
# Nearest to at: near, stanislavski, during, within, doggy, on, deposit, ars,
# Nearest to with: between, while, denotation, exploding, ois, harkonnen, into, when,
# Nearest to if: when, though, where, because, although, for, before, could,
# Nearest to is: was, has, are, be, becomes, although, by, contains,
# Nearest to also: still, now, often, sometimes, usually, which, generally, never,
# Nearest to united: nand, buu, baton, tornadoes, heil, shaded, bca, transformer,
# Nearest to war: lusignan, satisfying, alen, celebrated, ley, billings, biola, ramgoolam,
# Average loss at step 72000: 3.368581
# Average loss at step 74000: 3.349454
# Average loss at step 76000: 3.314600
# Average loss at step 78000: 3.346869
# Average loss at step 80000: 3.379769
# Nearest to these: several, many, such, those, both, some, various, multiple,
# Nearest to often: sometimes, usually, generally, commonly, still, widely, typically, also,
# Nearest to than: or, dieu, much, while, but, handicap, detects, far,
# Nearest to on: upon, through, in, under, from, within, funimation, at,
# Nearest to history: list, vestal, motorway, enumerable, inference, cambridge, prophesied, indo,
# Nearest to from: through, into, on, across, towards, under, during, after,
# Nearest to people: men, children, women, those, deputies, tons, individuals, soared,
# Nearest to not: still, usually, now, they, generally, gradually, premillennialism, it,
# Nearest to d: b, supra, omnipresent, e, f, x, g, n,
# Nearest to at: in, near, on, doggy, during, around, within, ars,
# Nearest to with: between, when, into, listeners, in, for, sinti, among,
# Nearest to if: when, though, where, before, although, because, boogie, involves,
# Nearest to is: was, are, has, remains, although, were, became, unlicensed,
# Nearest to also: often, now, still, sometimes, usually, which, never, actually,
# Nearest to united: nand, baton, tornadoes, buu, shaded, bca, syrup, waving,
# Nearest to war: wars, alen, celebrated, logarithmically, satisfying, monastic, billings, biola,
# Average loss at step 82000: 3.412601
# Average loss at step 84000: 3.408994
# Average loss at step 86000: 3.388547
# Average loss at step 88000: 3.350817
# Average loss at step 90000: 3.370968
# Nearest to these: several, many, some, multiple, are, various, which, those,
# Nearest to often: sometimes, usually, commonly, generally, still, also, frequently, widely,
# Nearest to than: dieu, handicap, detects, much, amoeba, dsp, or, circassians,
# Nearest to on: upon, under, through, at, within, in, ota, against,
# Nearest to history: list, smuggling, vestal, spinach, inference, destruct, portals, study,
# Nearest to from: through, into, towards, during, mosque, toward, llama, before,
# Nearest to people: children, men, women, man, citizens, deputies, jews, those,
# Nearest to not: still, now, premillennialism, almost, partially, gradually, generally, usually,
# Nearest to d: b, omnipresent, supra, n, h, g, f, l,
# Nearest to at: during, near, in, towards, under, around, dannebrog, on,
# Nearest to with: between, in, ois, arias, when, by, using, within,
# Nearest to if: when, where, though, before, without, although, since, for,
# Nearest to is: was, has, are, although, contains, makes, be, does,
# Nearest to also: often, still, now, which, sometimes, actually, usually, never,
# Nearest to united: nand, buu, tornadoes, constitution, baton, shaded, quarterfinals, bca,
# Nearest to war: wars, logarithmically, celebrated, gamemasters, monastic, billings, alen, battle,
# Average loss at step 92000: 3.397364
# Average loss at step 94000: 3.251044
# Average loss at step 96000: 3.357236
# Average loss at step 98000: 3.243633
# Average loss at step 100000: 3.357411
# Nearest to these: several, many, some, multiple, various, those, were, which,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, widely, still,
# Nearest to than: or, much, barrelled, dieu, circassians, detects, handicap, amoeba,
# Nearest to on: upon, through, in, at, bonny, within, zork, under,
# Nearest to history: list, smuggling, study, portals, vestal, enumerable, inference, financing,
# Nearest to from: through, into, towards, in, across, during, sweeney, racetrack,
# Nearest to people: men, children, citizens, women, jews, americans, deputies, individuals,
# Nearest to not: still, now, almost, partially, generally, never, they, also,
# Nearest to d: b, supra, pinyin, x, elric, incisors, cloistered, omnipresent,
# Nearest to at: in, near, on, during, after, dannebrog, within, describes,
# Nearest to with: between, sinti, psychometrics, at, using, including, exempted, landmark,
# Nearest to if: when, where, though, while, because, without, before, although,
# Nearest to is: was, has, be, becomes, became, malleus, are, appears,
# Nearest to also: still, now, often, sometimes, never, actually, generally, usually,
# Nearest to united: nand, tornadoes, shaded, buu, constitution, quarterfinals, centripetal, baton,
# Nearest to war: wars, battle, alen, vitally, celebrated, monastic, billings, gamemasters,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
