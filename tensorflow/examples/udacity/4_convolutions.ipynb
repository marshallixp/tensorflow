# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.014664
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.364828
# Minibatch accuracy: 37.5%
# Validation accuracy: 49.5%
# Minibatch loss at step 100: 1.195611
# Minibatch accuracy: 62.5%
# Validation accuracy: 72.1%
# Minibatch loss at step 150: 0.369055
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 200: 0.904279
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 0.685511
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 300: 0.255199
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 350: 0.285658
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 400: 1.164165
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 450: 0.928877
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 500: 0.408325
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 550: 0.451551
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 600: 0.814980
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 650: 0.264150
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 0.815361
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 750: 0.906841
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.726048
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 850: 0.719496
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 900: 0.543556
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 950: 0.648000
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.318907
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.5%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

  def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.relu(conv2d(data, layer1_weights) + layer1_biases)
    pool = max_pool_2x2(conv)
    conv = tf.nn.relu(conv2d(pool, layer2_weights) + layer2_biases)
    hidden = max_pool_2x2(conv)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases

  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.043660
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.415599
# Minibatch accuracy: 0.0%
# Validation accuracy: 8.3%
# Minibatch loss at step 100: 2.284633
# Minibatch accuracy: 12.5%
# Validation accuracy: 15.2%
# Minibatch loss at step 150: 2.364585
# Minibatch accuracy: 0.0%
# Validation accuracy: 15.2%
# Minibatch loss at step 200: 2.062164
# Minibatch accuracy: 25.0%
# Validation accuracy: 26.2%
# Minibatch loss at step 250: 2.109114
# Minibatch accuracy: 12.5%
# Validation accuracy: 17.7%
# Minibatch loss at step 300: 1.862334
# Minibatch accuracy: 25.0%
# Validation accuracy: 30.2%
# Minibatch loss at step 350: 2.042108
# Minibatch accuracy: 6.2%
# Validation accuracy: 26.4%
# Minibatch loss at step 400: 2.397424
# Minibatch accuracy: 12.5%
# Validation accuracy: 27.1%
# Minibatch loss at step 450: 1.903492
# Minibatch accuracy: 43.8%
# Validation accuracy: 29.8%
# Minibatch loss at step 500: 1.605045
# Minibatch accuracy: 62.5%
# Validation accuracy: 40.2%
# Minibatch loss at step 550: 1.239737
# Minibatch accuracy: 62.5%
# Validation accuracy: 43.1%
# Minibatch loss at step 600: 1.227308
# Minibatch accuracy: 56.2%
# Validation accuracy: 56.7%
# Minibatch loss at step 650: 1.034161
# Minibatch accuracy: 62.5%
# Validation accuracy: 58.8%
# Minibatch loss at step 700: 1.570150
# Minibatch accuracy: 50.0%
# Validation accuracy: 47.4%
# Minibatch loss at step 750: 1.211899
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.4%
# Minibatch loss at step 800: 1.067060
# Minibatch accuracy: 75.0%
# Validation accuracy: 62.8%
# Minibatch loss at step 850: 1.283735
# Minibatch accuracy: 68.8%
# Validation accuracy: 64.2%
# Minibatch loss at step 900: 0.924341
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.9%
# Minibatch loss at step 950: 1.335263
# Minibatch accuracy: 56.2%
# Validation accuracy: 64.4%
# Minibatch loss at step 1000: 0.540957
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.2%
# Test accuracy: 76.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
dropout_p = 1

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

  def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
  
  # Model.
  def model(data):
    conv = tf.nn.relu(conv2d(data, layer1_weights) + layer1_biases)
    pool = max_pool_2x2(conv)
    conv = tf.nn.relu(conv2d(pool, layer2_weights) + layer2_biases)
    hidden = max_pool_2x2(conv)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases) #Add Dropout
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  logits_drop = tf.nn.dropout(logits, dropout_p)  
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits_drop, tf_train_labels))
    
  # Optimizer.
#   optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  global_step = tf.Variable(0)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.05, global_step, 10000, 0.96)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits_drop)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.458935
# Minibatch accuracy: 10.2%
# Validation accuracy: 9.3%
# Minibatch loss at step 50: 1.485656
# Minibatch accuracy: 49.2%
# Validation accuracy: 55.6%
# Minibatch loss at step 100: 0.808548
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.4%
# Minibatch loss at step 150: 0.771408
# Minibatch accuracy: 79.7%
# Validation accuracy: 79.8%
# Minibatch loss at step 200: 0.675696
# Minibatch accuracy: 85.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 250: 0.871251
# Minibatch accuracy: 73.4%
# Validation accuracy: 79.3%
# Minibatch loss at step 300: 0.445819
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.7%
# Minibatch loss at step 350: 0.621465
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 400: 0.608349
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 450: 0.608514
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 500: 0.670175
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 550: 0.694896
# Minibatch accuracy: 78.9%
# Validation accuracy: 84.1%
# Minibatch loss at step 600: 0.519156
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.5%
# Minibatch loss at step 650: 0.574364
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 700: 0.536727
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 750: 0.472201
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.8%
# Minibatch loss at step 800: 0.440672
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.3%
# Minibatch loss at step 850: 0.516855
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 900: 0.586782
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 950: 0.618951
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.3%
# Minibatch loss at step 1000: 0.374813
# Minibatch accuracy: 91.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 1050: 0.453739
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.0%
# Minibatch loss at step 1100: 0.424742
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.9%
# Minibatch loss at step 1150: 0.404404
# Minibatch accuracy: 88.3%
# Validation accuracy: 86.4%
# Minibatch loss at step 1200: 0.381077
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.1%
# Minibatch loss at step 1250: 0.524587
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 1300: 0.556644
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 1350: 0.533090
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 1400: 0.318749
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 1450: 0.582372
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 1500: 0.354832
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.9%
# Minibatch loss at step 1550: 0.443846
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 1600: 0.526037
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 1650: 0.312463
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 1700: 0.392176
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.0%
# Minibatch loss at step 1750: 0.374989
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.1%
# Minibatch loss at step 1800: 0.400184
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 1850: 0.422196
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 1900: 0.491873
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 1950: 0.509958
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 2000: 0.531593
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 2050: 0.402483
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 2100: 0.308864
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 2150: 0.364069
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.7%
# Minibatch loss at step 2200: 0.347354
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 2250: 0.493589
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.8%
# Minibatch loss at step 2300: 0.283069
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.0%
# Minibatch loss at step 2350: 0.361518
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.0%
# Minibatch loss at step 2400: 0.420987
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.9%
# Minibatch loss at step 2450: 0.494546
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 2500: 0.429027
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.0%
# Minibatch loss at step 2550: 0.368771
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# Minibatch loss at step 2600: 0.238638
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.0%
# Minibatch loss at step 2650: 0.311009
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 2700: 0.411059
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 2750: 0.444270
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.1%
# Minibatch loss at step 2800: 0.437992
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 2850: 0.449849
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 2900: 0.405481
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# Minibatch loss at step 2950: 0.408780
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.6%
# Minibatch loss at step 3000: 0.215779
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 3050: 0.379076
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 3100: 0.503743
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 3150: 0.399744
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.4%
# Minibatch loss at step 3200: 0.316768
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 3250: 0.327411
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 3300: 0.234393
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 3350: 0.487393
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 3400: 0.415145
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 3450: 0.502636
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 3500: 0.304135
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 3550: 0.483791
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.7%
# Minibatch loss at step 3600: 0.239644
# Minibatch accuracy: 93.0%
# Validation accuracy: 88.6%
# Minibatch loss at step 3650: 0.253493
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 3700: 0.409771
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.7%
# Minibatch loss at step 3750: 0.272755
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.6%
# Minibatch loss at step 3800: 0.288276
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 3850: 0.473003
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 3900: 0.250380
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.7%
# Minibatch loss at step 3950: 0.262898
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 4000: 0.404892
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.8%
# Minibatch loss at step 4050: 0.309103
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.8%
# Minibatch loss at step 4100: 0.297484
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.8%
# Minibatch loss at step 4150: 0.354434
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 4200: 0.463310
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 4250: 0.418870
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 4300: 0.633737
# Minibatch accuracy: 82.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 4350: 0.241309
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 4400: 0.258802
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 4450: 0.226890
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 4500: 0.216957
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 4550: 0.353129
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 4600: 0.315701
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 4650: 0.435136
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 4700: 0.282442
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 4750: 0.332865
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.9%
# Minibatch loss at step 4800: 0.386267
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 4850: 0.316730
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.1%
# Minibatch loss at step 4900: 0.262738
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 4950: 0.393082
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 5000: 0.397605
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.2%
# Test accuracy: 94.7%

# %%
# Best Record 94.7%
